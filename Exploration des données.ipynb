# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Importation des données non cleanées

# %%
df=pd.read_table("food.txt",sep="\t")
df.head(10)
# Out:
# /var/folders/64/xbnl04752rd562f9w8d832xh0000gn/T/ipykernel_81545/2885447575.py:1: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,35,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_table("food.txt",sep="\t")
#     code                                                url  \
# 0   3087  http://world-fr.openfoodfacts.org/produit/0000...
# 1   4530  http://world-fr.openfoodfacts.org/produit/0000...
# 2   4559  http://world-fr.openfoodfacts.org/produit/0000...
# 3  16087  http://world-fr.openfoodfacts.org/produit/0000...
# 4  16094  http://world-fr.openfoodfacts.org/produit/0000...
# 5  16100  http://world-fr.openfoodfacts.org/produit/0000...
# 6  16117  http://world-fr.openfoodfacts.org/produit/0000...
# 7  16124  http://world-fr.openfoodfacts.org/produit/0000...
# 8  16193  http://world-fr.openfoodfacts.org/produit/0000...
# 9  16513  http://world-fr.openfoodfacts.org/produit/0000...
#
# ...

# %%
pd.set_option("display.max_columns", None)
df
# Out:
#                  code                                                url  \
# 0                3087  http://world-fr.openfoodfacts.org/produit/0000...
# 1                4530  http://world-fr.openfoodfacts.org/produit/0000...
# 2                4559  http://world-fr.openfoodfacts.org/produit/0000...
# 3               16087  http://world-fr.openfoodfacts.org/produit/0000...
# 4               16094  http://world-fr.openfoodfacts.org/produit/0000...
# ...               ...                                                ...
# 320767  9948282780603  http://world-fr.openfoodfacts.org/produit/9948...
# 320768       99567453  http://world-fr.openfoodfacts.org/produit/9956...
# 320769  9970229501521  http://world-fr.openfoodfacts.org/produit/9970...
# 320770  9980282863788  http://world-fr.openfoodfacts.org/produit/9980...
# 320771   999990026839  http://world-fr.openfoodfacts.org/produit/9999...
#
#                            creator   created_t      created_datetime  \
# ...

# %% [markdown]
# # Info sur le dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320772 entries, 0 to 320771
# Columns: 162 entries, code to water-hardness_100g
# dtypes: float64(106), object(56)
# memory usage: 396.5+ MB

# %% [markdown]
# # Importation des données cleanées

# %%
dataset=pd.read_csv("dataset_nettoyé.csv")
dataset.head()
# Out:
#    Unnamed: 0                    product_name           brands countries_fr  \
# 0           0              Farine de blé noir  Ferme t'y R'nao       France
# 1           1  Banana Chips Sweetened (Whole)        Carrefour   États-Unis
# 2           2                         Peanuts   Torn & Glasser   États-Unis
# 3           3          Organic Salted Nut Mix        Grizzlies   États-Unis
# 4           4                 Organic Polenta   Bob's Red Mill   États-Unis
#
#    energy_100g  fat_100g  saturated-fat_100g  carbohydrates_100g  sugars_100g  \
# 0       1100.0      5.00                1.79               20.60         5.71
# 1       2243.0     28.57               28.57               64.29        14.29
# 2       1941.0     17.86                0.00               60.71        17.86
# 3       2540.0     57.14                5.36               17.86         3.57
# 4       1552.0      1.43                1.79               77.14         5.71
#
# ...

# %%
dataset= dataset.drop(columns=["Unnamed: 0"])

# %%
 dataset.describe(include="all")
# Out:
#        product_name     brands countries_fr   energy_100g       fat_100g  \
# count        298606     298606       298606  2.986060e+05  298606.000000
# unique       221347      58784          722           NaN            NaN
# top       Ice Cream  Carrefour   États-Unis           NaN            NaN
# freq           4571      18078       166118           NaN            NaN
# mean            NaN        NaN          NaN  1.135884e+03      11.076856
# std             NaN        NaN          NaN  6.027014e+03      15.688108
# min             NaN        NaN          NaN  0.000000e+00       0.000000
# 25%             NaN        NaN          NaN  4.760000e+02       0.800000
# 50%             NaN        NaN          NaN  1.100000e+03       5.000000
# 75%             NaN        NaN          NaN  1.594000e+03      15.330000
# max             NaN        NaN          NaN  3.251373e+06     100.000000
#
#         saturated-fat_100g  carbohydrates_100g    sugars_100g     fiber_100g  \
# ...

# %%
dataset.nunique()
# Out:
# product_name               221347
# brands                      58784
# countries_fr                  722
# energy_100g                  3997
# fat_100g                     3374
# saturated-fat_100g           2194
# carbohydrates_100g           5401
# sugars_100g                  4052
# fiber_100g                   1011
# proteins_100g                2499
# salt_100g                    5511
# nutrition-score-fr_100g        55
# dtype: int64

# %% [markdown]
# # Analyse multivariée

# %%
dataset.corr()
# Out:
#                          energy_100g  fat_100g  saturated-fat_100g  \
# energy_100g                 1.000000  0.088081            0.067904
# fat_100g                    0.088081  1.000000            0.648262
# saturated-fat_100g          0.067904  0.648262            1.000000
# carbohydrates_100g          0.059355 -0.047832           -0.017230
# sugars_100g                 0.036468 -0.018941            0.101589
# fiber_100g                  0.038447  0.119213            0.013050
# proteins_100g               0.040174  0.238050            0.189154
# salt_100g                  -0.010518 -0.039164           -0.024094
# nutrition-score-fr_100g     0.065630  0.448585            0.571344
#
#                          carbohydrates_100g  sugars_100g  fiber_100g  \
# energy_100g                        0.059355     0.036468    0.038447
# fat_100g                          -0.047832    -0.018941    0.119213
# saturated-fat_100g                -0.017230     0.101589    0.013050
# ...

# %%
dataset[["energy_100g","saturated-fat_100g","carbohydrates_100g","sugars_100g","fat_100g","nutrition-score-fr_100g"]].corr()
# Out:
#                          energy_100g  saturated-fat_100g  carbohydrates_100g  \
# energy_100g                 1.000000            0.067904            0.059355
# saturated-fat_100g          0.067904            1.000000           -0.017230
# carbohydrates_100g          0.059355           -0.017230            1.000000
# sugars_100g                 0.036468            0.101589            0.639129
# fat_100g                    0.088081            0.648262           -0.047832
# nutrition-score-fr_100g     0.065630            0.571344            0.213486
#
#                          sugars_100g  fat_100g  nutrition-score-fr_100g
# energy_100g                 0.036468  0.088081                 0.065630
# saturated-fat_100g          0.101589  0.648262                 0.571344
# carbohydrates_100g          0.639129 -0.047832                 0.213486
# sugars_100g                 1.000000 -0.018941                 0.406258
# ...

# %%
hm=dataset.iloc[:,3:12]
plt.figure(figsize=(8,8))
sb.heatmap(hm.corr(), annot=True, cmap="winter")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analyse bivariée

# %%
hm=dataset.iloc[:,5:13]
sb.pairplot(hm , height=2)

# %% [markdown]
# # Analyse Univariée

# %%
plt.hist(dataset["nutrition-score-fr_100g"] ,bins=30)
plt.show()

# %%
plt.hist(dataset["saturated-fat_100g"] ,bins=30)
plt.show()

# %%
plt.hist(dataset["sugars_100g"] ,bins=30)
plt.show()

# %%
plt.hist(dataset["carbohydrates_100g"] ,bins=30)
plt.show()

# %%
plt.hist(dataset["fat_100g"] ,bins=30)
plt.show()

# %%
plt.hist(dataset["fiber_100g"] ,bins=30)
plt.show()

# %%
plt.hist(dataset["proteins_100g"] ,bins=30)
plt.show()

# %%
plt.hist(dataset["energy_100g"] ,bins=15)
plt.show()

# %%
mv=dataset["nutrition-score-fr_100g"]
mv.idxmax()
# Out:
# 52974

# %%
mv=dataset["nutrition-score-fr_100g"]
mv.idxmin()
# Out:
# 217558

# %%
dataset.iloc[217558]
# Out:
# product_name               Pois chiches
# brands                          Primeal
# countries_fr                     France
# energy_100g                       317.0
# fat_100g                            3.4
# saturated-fat_100g                  0.7
# carbohydrates_100g                 41.2
# sugars_100g                         2.4
# fiber_100g                         21.4
# proteins_100g                      19.8
# salt_100g                          0.06
# nutrition-score-fr_100g           -15.0
# Name: 217558, dtype: object

# %%
dataset.iloc[52974]
# Out:
# product_name               Maxwell House, Creme Cappuccino
# brands                                             Tassimo
# countries_fr                                    États-Unis
# energy_100g                                         4184.0
# fat_100g                                             56.25
# saturated-fat_100g                                    37.5
# carbohydrates_100g                                    75.0
# sugars_100g                                           75.0
# fiber_100g                                             0.0
# proteins_100g                                         37.5
# salt_100g                                          3.33248
# nutrition-score-fr_100g                               40.0
# Name: 52974, dtype: object

# %% [markdown]
# # visualisation des donnéés nutriscore sur [-10,10] et [20,40]

# %%
df = dataset[(dataset['nutrition-score-fr_100g']>-11) & (dataset['nutrition-score-fr_100g']<11)]

# %%
sb.pairplot(df ,height=2)

# %%
DF = dataset[(dataset['nutrition-score-fr_100g']>21) & (dataset['nutrition-score-fr_100g']<39)]

# %%
sb.pairplot(DF ,height=2)

# %%
H= dataset[(dataset['nutrition-score-fr_100g']==-10)]

# %%
H.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 11965 to 297386
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   product_name             158 non-null    object
#  1   brands                   158 non-null    object
#  2   countries_fr             158 non-null    object
#  3   energy_100g              158 non-null    float64
#  4   fat_100g                 158 non-null    float64
#  5   saturated-fat_100g       158 non-null    float64
#  6   carbohydrates_100g       158 non-null    float64
#  7   sugars_100g              158 non-null    float64
#  8   fiber_100g               158 non-null    float64
#  9   proteins_100g            158 non-null    float64
#  10  salt_100g                158 non-null    float64
#  11  nutrition-score-fr_100g  158 non-null    float64
# dtypes: float64(9), object(3)
# memory usage: 16.0+ KB

# %%
I= dataset[(dataset['nutrition-score-fr_100g']==-2)]

# %%
I
# Out:
#                                          product_name  \
# 173                             Fresh Organic Carrots
# 444                                  Chicken pad thaï
# 528                       British Beef Braising Steak
# 573                              Spicy Black Bean Dip
# 611                                Organic Great Seed
# ...                                               ...
# 298135                                           Oats
# 298172  Sydney City Oysters Fresh Sydney Rock Oysters
# 298251    Annies Fruit Snack Strawberry Fruit Leather
# 298309                     Supersoft Honeygrain Toast
# 298463                    Baked Beans In Tomato Sauce
#
#                             brands        countries_fr  energy_100g  fat_100g  \
# 173                      Bunny-Luv          États-Unis        159.0      0.00
# 444                MARKS & SPENCER  France,Royaume-Uni        619.0      5.00
# 528     Simply M&S,Marks & Spencer         Royaume-Uni        615.0      6.40
# ...

# %%
I.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6025 entries, 173 to 298463
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   product_name             6025 non-null   object
#  1   brands                   6025 non-null   object
#  2   countries_fr             6025 non-null   object
#  3   energy_100g              6025 non-null   float64
#  4   fat_100g                 6025 non-null   float64
#  5   saturated-fat_100g       6025 non-null   float64
#  6   carbohydrates_100g       6025 non-null   float64
#  7   sugars_100g              6025 non-null   float64
#  8   fiber_100g               6025 non-null   float64
#  9   proteins_100g            6025 non-null   float64
#  10  salt_100g                6025 non-null   float64
#  11  nutrition-score-fr_100g  6025 non-null   float64
# dtypes: float64(9), object(3)
# memory usage: 611.9+ KB

# %%
P= dataset[(dataset['nutrition-score-fr_100g']==40)]

# %%
P
# Out:
#                                  product_name    brands countries_fr  \
# 52974         Maxwell House, Creme Cappuccino   Tassimo   États-Unis
# 52975   Cafe Collection Coffee & Milk Creamer   Tassimo   États-Unis
# 53001                   Coffee & Milk Creamer   Tassimo   États-Unis
# 168627            Cappuccino allégé en sucre*  Bellarom       France
#
#         energy_100g  fat_100g  saturated-fat_100g  carbohydrates_100g  \
# 52974        4184.0     56.25               37.50               75.00
# 52975        4707.0     75.00               43.75               87.50
# 53001        5577.0    100.00               58.33               66.67
# 168627       1603.0     14.60               13.40               51.30
#
#         sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# 52974         75.00         0.0          37.50    3.33248
# 52975         75.00         0.0          50.00    3.96748
# 53001         66.67         0.0          66.67    6.35000
# ...

# %%
G = dataset[(dataset['nutrition-score-fr_100g']>-16) & (dataset['nutrition-score-fr_100g']<-1)]

# %%
G.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26227 entries, 19 to 298590
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   product_name             26227 non-null  object
#  1   brands                   26227 non-null  object
#  2   countries_fr             26227 non-null  object
#  3   energy_100g              26227 non-null  float64
#  4   fat_100g                 26227 non-null  float64
#  5   saturated-fat_100g       26227 non-null  float64
#  6   carbohydrates_100g       26227 non-null  float64
#  7   sugars_100g              26227 non-null  float64
#  8   fiber_100g               26227 non-null  float64
#  9   proteins_100g            26227 non-null  float64
#  10  salt_100g                26227 non-null  float64
#  11  nutrition-score-fr_100g  26227 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 2.6+ MB

# %%
sb.pairplot(G ,height=2)

# %%
G.describe()
# Out:
#         energy_100g      fat_100g  saturated-fat_100g  carbohydrates_100g  \
# count  26227.000000  26227.000000        26227.000000        26227.000000
# mean     750.062001      2.583828            0.342893           30.127514
# std      567.759233      3.975162            0.622064           27.570675
# min        0.000000      0.000000            0.000000            0.000000
# 25%      265.000000      0.200000            0.000000            7.500000
# 50%      487.000000      1.670000            0.000000           17.570000
# 75%     1445.500000      3.570000            0.500000           60.420000
# max     2923.000000     72.000000            7.300000          100.000000
#
#         sugars_100g    fiber_100g  proteins_100g     salt_100g  \
# count  26227.000000  26227.000000   26227.000000  26227.000000
# mean       3.263148      4.985367       8.681704      0.290265
# std        3.817070      6.635912       7.013652      0.360851
# ...

# %%
G
# Out:
#                                     product_name              brands  \
# 19                            Organic Oat Groats                 Pcc
# 173                        Fresh Organic Carrots           Bunny-Luv
# 263     Organic Flourless Sprouted 7-Grain Bread        Trader Joe's
# 327                               Romaine Hearts    Ocean Mist Farms
# 328                                      Romaine    Ocean Mist Farms
# ...                                          ...                 ...
# 298394                        Ananas en morceaux            Mainstay
# 298419                                  Total 2%                Fage
# 298463               Baked Beans In Tomato Sauce                Ayam
# 298482                   Ayam Pure Coconut Water                Ayam
# 298590       Tartines craquantes bio au sarrasin  Le Pain des fleurs
#
#             countries_fr  energy_100g  fat_100g  saturated-fat_100g  \
# 19            États-Unis       1096.0      5.95                1.19
# ...

# %%
Z = dataset[(dataset['nutrition-score-fr_100g']>-16) & (dataset['nutrition-score-fr_100g']<-1)]

# %%
Z.describe()
# Out:
#         energy_100g      fat_100g  saturated-fat_100g  carbohydrates_100g  \
# count  26227.000000  26227.000000        26227.000000        26227.000000
# mean     750.062001      2.583828            0.342893           30.127514
# std      567.759233      3.975162            0.622064           27.570675
# min        0.000000      0.000000            0.000000            0.000000
# 25%      265.000000      0.200000            0.000000            7.500000
# 50%      487.000000      1.670000            0.000000           17.570000
# 75%     1445.500000      3.570000            0.500000           60.420000
# max     2923.000000     72.000000            7.300000          100.000000
#
#         sugars_100g    fiber_100g  proteins_100g     salt_100g  \
# count  26227.000000  26227.000000   26227.000000  26227.000000
# mean       3.263148      4.985367       8.681704      0.290265
# std        3.817070      6.635912       7.013652      0.360851
# ...

# %%
Z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26227 entries, 19 to 298590
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   product_name             26227 non-null  object
#  1   brands                   26227 non-null  object
#  2   countries_fr             26227 non-null  object
#  3   energy_100g              26227 non-null  float64
#  4   fat_100g                 26227 non-null  float64
#  5   saturated-fat_100g       26227 non-null  float64
#  6   carbohydrates_100g       26227 non-null  float64
#  7   sugars_100g              26227 non-null  float64
#  8   fiber_100g               26227 non-null  float64
#  9   proteins_100g            26227 non-null  float64
#  10  salt_100g                26227 non-null  float64
#  11  nutrition-score-fr_100g  26227 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 2.6+ MB

# %%
X = dataset[(dataset['nutrition-score-fr_100g']>-3) & (dataset['nutrition-score-fr_100g']<16)]

# %%
X.describe()
# Out:
#         energy_100g       fat_100g  saturated-fat_100g  carbohydrates_100g  \
# count  2.202190e+05  220219.000000       220219.000000       220219.000000
# mean   9.846906e+02       8.261743            2.436657           27.108177
# std    6.977486e+03      14.102691            4.503164           25.277879
# min    0.000000e+00       0.000000            0.000000            0.000000
# 25%    3.850000e+02       0.100000            0.100000            9.000000
# 50%    1.100000e+03       5.000000            1.790000           20.600000
# 75%    1.289000e+03       7.900000            2.000000           35.290000
# max    3.251373e+06     100.000000          100.000000          100.000000
#
#          sugars_100g     fiber_100g  proteins_100g      salt_100g  \
# count  220219.000000  220219.000000  220219.000000  220219.000000
# mean       11.864100       2.223080       5.832973       1.534585
# std        18.017157       3.397235       6.915411       6.803837
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 220219 entries, 0 to 298605
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   product_name             220219 non-null  object
#  1   brands                   220219 non-null  object
#  2   countries_fr             220219 non-null  object
#  3   energy_100g              220219 non-null  float64
#  4   fat_100g                 220219 non-null  float64
#  5   saturated-fat_100g       220219 non-null  float64
#  6   carbohydrates_100g       220219 non-null  float64
#  7   sugars_100g              220219 non-null  float64
#  8   fiber_100g               220219 non-null  float64
#  9   proteins_100g            220219 non-null  float64
#  10  salt_100g                220219 non-null  float64
#  11  nutrition-score-fr_100g  220219 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 21.8+ MB

# %%
L= dataset[(dataset['nutrition-score-fr_100g']>16) & (dataset['nutrition-score-fr_100g']<41)]

# %%
L.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51710 entries, 32 to 298553
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   product_name             51710 non-null  object
#  1   brands                   51710 non-null  object
#  2   countries_fr             51710 non-null  object
#  3   energy_100g              51710 non-null  float64
#  4   fat_100g                 51710 non-null  float64
#  5   saturated-fat_100g       51710 non-null  float64
#  6   carbohydrates_100g       51710 non-null  float64
#  7   sugars_100g              51710 non-null  float64
#  8   fiber_100g               51710 non-null  float64
#  9   proteins_100g            51710 non-null  float64
#  10  salt_100g                51710 non-null  float64
#  11  nutrition-score-fr_100g  51710 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 5.1+ MB

# %%
L.describe()
# Out:
#          energy_100g      fat_100g  saturated-fat_100g  carbohydrates_100g  \
# count   51710.000000  51710.000000        51710.000000        51710.000000
# mean     1863.791139     25.459222           13.332220           38.819135
# std      1246.727248     16.181668            9.316194           27.090594
# min         0.000000      0.000000            0.000000            0.000000
# 25%      1519.000000     16.130000            7.700000            8.700000
# 50%      1859.000000     24.400000           12.000000           46.670000
# 75%      2175.000000     32.140000           17.860000           61.180000
# max    231199.000000    100.000000          100.000000          100.000000
#
#         sugars_100g    fiber_100g  proteins_100g     salt_100g  \
# count  51710.000000  51710.000000   51710.000000  51710.000000
# mean      25.763685      1.819447       9.396950      1.617822
# std       22.092932      2.945418       8.943287      3.668148
# ...

# %% [markdown]
# # Réduction dimensionnelle

# %% [markdown]
# Pour raison d'esthétique j'ai fait la partie "réduction dimensionnelle" sur un autre Notebook appelé "réduction des dimensions" dans ce même livrable.
